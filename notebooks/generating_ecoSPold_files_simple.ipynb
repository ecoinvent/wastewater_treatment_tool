# %%
import os
import pickle

# %%
os.chdir('C:\mypy\code\wastewater_treatment_tool')
from pycode import *

# %% [markdown]
# ## Admin functions, required before tool can be used

# %% [markdown]
# ### Generate master data dictionary and store to pickle

# %% [markdown]
# #### Arguments (change these to what you need them to be to work on server implementation)

# %%
# Location where the pickled master data dict (MD) is stored. 
# If it doesn't exist, it will be generated.
MD_pkl_dir = r'C:\mypy\code\wastewater_treatment_tool\MasterData'

# Location of directory with master data xml files
MD_xlm_dir = r'C:\mypy\code\wastewater_treatment_tool\MasterData\XML'

# Location of file "MasterData_fields.xlsx"
MD_fields_xls = r'C:\mypy\code\wastewater_treatment_tool\MasterData\xlsx\MasterData_fields.xlsx'

# Optional, filepath to where an Excel version of the dictionary will be dumped
# Not used by tool, but can be useful to humans during development
MD_xls_dump_dir=r'C:\mypy\code\wastewater_treatment_tool\MasterData\xlsx'

# %% [markdown]
# #### Running function (test)

# %%
MD = load_MD(MD_pkl_dir, MD_xlm_dir, MD_fields_xls, MD_xls_dump_dir, return_MD=False)
# Out:
# Master data pkl being updated
