# %%
import os
from waste_water_tool import generate_new_MD_pickle
import pickle

# %% [markdown]
# ## Admin functions, required before tool can be used

# %% [markdown]
# ### Generate master data dictionary and store to pickle

# %% [markdown]
# #### Arguments (change these to what you need them to be to work on server implementation)

# %%
# Location of directory with master data xml files
MD_xlm_dir = r'C:\Users\Pascal Lesage\Documents\ecoinvent\EcoEditor\xml\MasterData\Production'

# Location of file "MasterData_fields.xlsx"
md_fields_xls = r'C:\mypy\code\wastewater_treatment_tool\waste_water_tool\documentation\MasterData_fields.xlsx'

# Location where pickled master data dict (MD) will be dumped. This is what the tool will use
MD_pkl_dir = r'C:/mypy/quick/wwt'

# Optional, filepath to where an Excel version of the dictionary will be dumped
# Not used by tool, but can be useful to humans during development
xls_MD_dump_dir=r'C:/mypy/quick/wwt'

# %% [markdown]
# #### Running function (test)

# %%
generate_new_MD_pickle(MD_dir=MD_dir, md_fields_xls=md_fields_xls, pickle_dump_dir=pickle_dump_dir)
# Out:
# 'C:/mypy/quick/wwt\\MD.pkl'

# %%
MD = load_MD(MD_pkl_dir, MD_xml_dir, md_fields_xls=None)

# %%
MD = pickle.load(open(r"C:/mypy/quick/wwt/MD.pkl", 'rb'))
