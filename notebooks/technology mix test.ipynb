# %%
import os
import sys
os.chdir('C:\mypy\code\wastewater_treatment_tool')
from pycode import *

# %%
sys.path.append('pycode')

# %%
from defaults import *

# %%
technologies_averaged = [
    {
        'fraction':0.5,
        'technology_str':"111",
        'capacity': "capacity description",
        'location': "GLO"
    },
    {
        'fraction':0.3,
        'technology_str':"11111",
        'capacity': "other capacity description",
        'location': "GLO"
    },
    {
        'fraction':0.2,
        'technology_str':"11011",
        'capacity': "yet other capacity description",
        'location': "GLO"
    },
]

# %%
print(technology_mix_constructor(technologies_averaged))
# Out:
# Averaged technologies:
# 	Share: 50%;
# 		Technology summary: Primary settler, Aerobic BOD removal, Nitrification;
# 		Capacity: capacity description;
# 		Location: GLO
# 	Share: 30%;
# 		Technology summary: Primary settler, Aerobic BOD removal, Nitrification, Denitrification, Biological P removal;
# 		Capacity: other capacity description;
# 		Location: GLO
# 	Share: 20%;
# 		Technology summary: Primary settler, Aerobic BOD removal, Denitrification, Biological P removal;
# 		Capacity: yet other capacity description;
# 		Location: GLO
